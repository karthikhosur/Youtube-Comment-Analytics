# %%
i = []
while(True):
  i.append('a')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-cc018406b551>", line 3, in <module>
#     i.append('a')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 732, in getmodule
#     for modname, module in list(sys.modules.items()):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
 # Google Colab Setup
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/My Drive/Analytic-Steps-blogs')

# %% [markdown]
# Install the relevant libraries

# %% [markdown]
# ## Install the google client library
#
# ### For Windows:
#
# `pip install google-api-python-client`
#
# ### For Ubuntu
#
# `sudo pip install google-api-python-client`
#
# ### For Anaconda
#
# `conda install google-api-python-client`

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (1.7.12)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.7.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.12.0)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (47.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth>=1.4.1->google-api-python-client) (0.4.8)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
conda install google-api-python-client
conda install -c anaconda pandas

# %%
from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# There are many resources available with the API which can be retreieved from the youtube.They include:
#
# *   **Channel** It contains information about the channel of youtube. Information like total number of videos including their total likes/dislikes, comments and subscriber etc.
# *   Playlists

# %%
youTubeApiKey="AIzaSyCPUs9IaX2LZwOLAjgY5f9ZEyJXFcLI43U"
youtube=build('youtube','v3',developerKey=youTubeApiKey)

# %% [markdown]
# In the next step we will try to find out the channel id and the related information using the <b>display name</b> of channel at youtube.<br>
# likewise I am using <b>NPTEL</b><br>
#
# Here we are going to find the details of channel resources.There are different properties, which can be used i.e. information corresponding to that property like
# * **snippet** which provide the basic details about the channel
# * **Statistics** provides the statistics of the channel

# %% [markdown]
# ## Resource - **Channel**
# ### Property - **Snippets**

# %%
snippets = youtube.search().list(part="snippet", type="channel", q="nptelhrd").execute()

# %%
snippets
# Out:
# {'etag': 'qsmNjSVedsOw_N5pRG2ol7yDxOI',
#  'items': [{'etag': 'yLSbOWADkef8HpffG8DpaLd7Rr0',
#    'id': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'channelTitle': 'nptelhrd',
#     'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...',
#     'liveBroadcastContent': 'upcoming',
#     'publishTime': '2007-11-28T04:54:13Z',
#     'publishedAt': '2007-11-28T04:54:13Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'nptelhrd'}},
#   {'etag': 'JzCwyqOaxjAXNuLGe1lH20-XeIg',
#    'id': {'channelId': 'UCTJn6buigC961hns17ELXAQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCTJn6buigC961hns17ELXAQ',
#     'channelTitle': 'Electrical Engineering',
#     'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:22:52Z',
#     'publishedAt': '2013-11-27T11:22:52Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Electrical Engineering'}},
#   {'etag': '-HDmD2hCjPaQ9BM-DNpQW0aNFw8',
#    'id': {'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ',
#     'channelTitle': 'Humanities and Social Sciences',
#     'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:27:07Z',
#     'publishedAt': '2013-11-27T11:27:07Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Humanities and Social Sciences'}},
#   {'etag': 'MUvLqSodJk6EzfYs1MjXexTADRs',
#    'id': {'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg',
#     'channelTitle': 'Civil Engineering',
#     'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:21:42Z',
#     'publishedAt': '2013-11-27T11:21:42Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Civil Engineering'}},
#   {'etag': '2BdoafKgnpYLCFbf2pIxoTzojoM',
#    'id': {'channelId': 'UC9vycSfjzLCR_w1C59VQo5A', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC9vycSfjzLCR_w1C59VQo5A',
#     'channelTitle': 'Physics',
#     'description': 'This channel contains technical lectures on "Physics" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore. Please ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:33:24Z',
#     'publishedAt': '2013-11-27T11:33:24Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Physics'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAUQAA',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 21},
#  'regionCode': 'US'}

# %%
print(snippets)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'qsmNjSVedsOw_N5pRG2ol7yDxOI', 'nextPageToken': 'CAUQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 21, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'yLSbOWADkef8HpffG8DpaLd7Rr0', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'JzCwyqOaxjAXNuLGe1lH20-XeIg', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Electrical Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:52Z'}}, {'kind': 'youtube#searchResult', 'etag': '-HDmD2hCjPaQ9BM-DNpQW0aNFw8', 'id': {'kind': 'youtube#channel', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ'}, 'snippet': {'publishedAt': '2013-11-27T11:27:07Z', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'title': 'Humanities and Social Sciences', 'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Humanities and Social Sciences', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:27:07Z'}}, {'kind': 'youtube#searchResult', 'etag': 'MUvLqSodJk6EzfYs1MjXexTADRs', 'id': {'kind': 'youtube#channel', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg'}, 'snippet': {'publishedAt': '2013-11-27T11:21:42Z', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'title': 'Civil Engineering', 'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Civil Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:21:42Z'}}, {'kind': 'youtube#searchResult' ...

# %%
for item in snippets:
  print(item)
# Out:
# kind
# etag
# nextPageToken
# regionCode
# pageInfo
# items

# %%
for key,value in snippets.items():
  print(key,"*************",value)
# Out:
# kind ************* youtube#searchListResponse
# etag ************* qsmNjSVedsOw_N5pRG2ol7yDxOI
# nextPageToken ************* CAUQAA
# regionCode ************* US
# pageInfo ************* {'totalResults': 21, 'resultsPerPage': 5}
# items ************* [{'kind': 'youtube#searchResult', 'etag': 'yLSbOWADkef8HpffG8DpaLd7Rr0', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'JzCwyqOaxjAXNuLGe1lH20-XeIg', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Electrical Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:52Z'}}, {'kind': 'youtube#searchResult', 'etag': '-HDmD2hCjPaQ9BM-DNpQW0aNFw8', 'id': {'kind': 'youtube#channel', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ'}, 'snippet': {'publishedAt': '2013-11-27T11:27:07Z', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'title': 'Humanities and Social Sciences', 'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Humanities and Social Sciences', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:27:07Z'}}, {'kind': 'youtube#searchResult', 'etag': 'MUvLqSodJk6EzfYs1MjXexTADRs', 'id': {'kind': 'youtube#channel', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg'}, 'snippet': {'publishedAt': '2013-11-27T11:21:42Z', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'title': 'Civil Engineering', 'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Civil Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:21:42Z'}}, {'kind': 'youtube#searchResult', 'etag': '2BdoafKgnpYLCFbf2pIxoTzojoM', 'id': {'kind': 'youtube#channel', 'channelId': 'UC9vycSfjzLCR_w1C59VQo5A'}, 'snippet': {'publishedAt': '2013-11-27T11:33:24Z', ' ...

# %%
for i in snippets['items']:
  print(i)
# Out:
# {'kind': 'youtube#searchResult', 'etag': 'yLSbOWADkef8HpffG8DpaLd7Rr0', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJwfq2GiltHYdlAHJycSsQKGFC_o_0yCR5fYwDNztg=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'JzCwyqOaxjAXNuLGe1lH20-XeIg', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJzRD3s64nZDuHQ2g45ZkAuppjqrLRbtIxUu-uc=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Electrical Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:52Z'}}
# {'kind': 'youtube#searchResult', 'etag': '-HDmD2hCjPaQ9BM-DNpQW0aNFw8', 'id': {'kind': 'youtube#channel', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ'}, 'snippet': {'publishedAt': '2013-11-27T11:27:07Z', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'title': 'Humanities and Social Sciences', 'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxEA5P1FLcEuka0c2f1So-p5fWAbw1-Iva2gqVW=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Humanities and Social Sciences', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:27:07Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'MUvLqSodJk6EzfYs1MjXexTADRs', 'id': {'kind': 'youtube#channel', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg'}, 'snippet': {'publishedAt': '2013-11-27T11:21:42Z', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'title': 'Civil Engineering', 'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJxhwzrBXaF8Tfq5v_WY224tUiM2oYyFmECxIVYt=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Civil Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:21:42Z'}}
# {'kind': 'youtube#searchResult', 'etag': '2BdoafKgnpYLCFbf2pIxoTzojoM', 'id': {'kind': 'youtube#channel', 'channelId': 'UC9vycSfjzLCR_w1C59VQo5A'}, 'snippet': {'publishedAt': '2013-11-27T11:33:24Z', 'channelId': 'UC9vycSfjzLCR_w1C59VQo5A', 'title': 'Physics', 'description': 'This channel contains technical lectures on "Physics" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore. Please ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/a/AATXAJyA9x40kJA6UoTU476utl0odTRf2a1CI55MkXU=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Physics', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:33:24Z'}}

# %% [markdown]
# From the above blocks of code we can see that by using property **snippets**  we got all the information related with the channel,actually information of all the related channels including **channelId, title, description,thumbnails and publishTime**

# %%
## Now extract the channelId,of the first channel in list, as follows: 

channelId = snippets['items'][0]['snippet']['channelId']

print("Channel ID of the first channel is "+ channelId)
# Out:
# Channel ID of the first channel is UC640y4UvDAlya_WOj5U4pfA

# %%
print("Channel "+snippets['items'][0]['snippet']['title'] +" is published at "+snippets['items'][0]['snippet']['publishedAt'])
print("Here is the description avaiable at the channel page on youtube \n")
print(snippets['items'][0]['snippet']['description'])
# Out:
# Channel nptelhrd is published at 2007-11-28T04:54:13Z
# Here is the description avaiable at the channel page on youtube
#
# Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...

# %% [markdown]
# ### Property - **Statistics**

# %%
stats = youtube.channels().list(part="statistics", id = channelId).execute()

# %%
stats['items']
# Out:
# [{'etag': 'XidHagqO1Rl-w3WW7esNl6GZVW8',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel',
#   'statistics': {'commentCount': '0',
#    'hiddenSubscriberCount': False,
#    'subscriberCount': '1770000',
#    'videoCount': '20311',
#    'viewCount': '382686614'}}]

# %%
stats
# Out:
# {'etag': 'YIO-CzyG7jFCUGqaC_TCho3bpwY',
#  'items': [{'etag': 'XidHagqO1Rl-w3WW7esNl6GZVW8',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel',
#    'statistics': {'commentCount': '0',
#     'hiddenSubscriberCount': False,
#     'subscriberCount': '1770000',
#     'videoCount': '20311',
#     'viewCount': '382686614'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1}}

# %%
for item in stats:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %% [markdown]
# In the following cell we will see the statistics of particular channel which we acquired using API, which includes **total subscribers, videoCounts, viewCounts**

# %%
print("Total Number of Subscribers of "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['subscriberCount'])
print("Total Number of Videos Uploaded at "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['videoCount'])
print("Total Number of view on all videos of "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['viewCount'])
# Out:
# Total Number of Subscribers of nptelhrd is 1770000
# Total Number of Videos Uploaded at nptelhrd is 20311
# Total Number of view on all videos of nptelhrd is 382686614

# %% [markdown]
# ### Property - **ContentDetails**
#
# In this we will get the details of all the videos related to that channel

# %%
content = youtube.channels().list(id = channelId, part = 'contentDetails').execute()
print(content)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'gl6KCyeby68dSSWI1LQEJNpX1hk', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'wJNFgVsFjcPi5W07m70UMpvvN1w', 'id': 'UC640y4UvDAlya_WOj5U4pfA', 'contentDetails': {'relatedPlaylists': {'likes': '', 'favorites': '', 'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}}}]}

# %%
content['items']
# Out:
# [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#     'likes': '',
#     'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}},
#   'etag': 'wJNFgVsFjcPi5W07m70UMpvvN1w',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel'}]

# %%
UploadId = content['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print("The Id of the upload playlist of this channel "+UploadId+" .In this playlist all the uploaded videos by this channels.")
# Out:
# The Id of the upload playlist of this channel UU640y4UvDAlya_WOj5U4pfA .In this playlist all the uploaded videos by this channels.

# %%
content
# Out:
# {'etag': 'gl6KCyeby68dSSWI1LQEJNpX1hk',
#  'items': [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#      'likes': '',
#      'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}},
#    'etag': 'wJNFgVsFjcPi5W07m70UMpvvN1w',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
for item in content:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %% [markdown]
# In the next cell you will see the playlists of the channel which includes the **liked and uploads** on the channel.<br>
# Liked videos include the videos liked by channel<br>Uploads will include the videos uploaded by the channel

# %%
content['items'][0]['contentDetails']['relatedPlaylists']
# Out:
# {'favorites': '', 'likes': '', 'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}

# %% [markdown]
# ### Property - **Status**
#
# It includes the information about the privacy status of the channel

# %%
status = youtube.channels().list(id = channelId, part = 'status').execute()
print(status)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'EQ6nRmhcHHZAZrMUUYRtXhyR8i0', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'roccK1BVy-xXoppN94kATuPPRW4', 'id': 'UC640y4UvDAlya_WOj5U4pfA', 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}}]}

# %%
status
# Out:
# {'etag': 'EQ6nRmhcHHZAZrMUUYRtXhyR8i0',
#  'items': [{'etag': 'roccK1BVy-xXoppN94kATuPPRW4',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel',
#    'status': {'isLinked': True,
#     'longUploadsStatus': 'longUploadsUnspecified',
#     'madeForKids': False,
#     'privacyStatus': 'public'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
for item in status:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %%
status['items'][0]['status']
# Out:
# {'isLinked': True,
#  'longUploadsStatus': 'longUploadsUnspecified',
#  'madeForKids': False,
#  'privacyStatus': 'public'}

# %%
print("Privacy Status of this channel is "+status['items'][0]['status']['privacyStatus'])
# Out:
# Privacy Status of this channel is public

# %%
if(status['items'][0]['status']['madeForKids'] == True):
  print("This channel include videos for Kids")
else:
  print("This channel is not for kids")
# Out:
# This channel is not for kids

# %% [markdown]
# ## Resources: **ChannelSection**

# %%
channelSections = youtube.channelSections().list(channelId = channelId, part = 'snippet').execute()

# %%
channelSections
# Out:
# {'etag': 'j6k3_EntqH237Ss2E9ZumFHacvI',
#  'items': [{'etag': 'XekCe8ltIbhOntsPpZP72KceSOI',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA.ZUhUjN8MMfo',
#    'kind': 'youtube#channelSection',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'position': 0,
#     'style': 'verticalList',
#     'type': 'recentUploads'}},
#   {'etag': 'GZ4Fn0dMaXHiX9T2pz3lRunvFdo',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA.nISYu77cYpo',
#    'kind': 'youtube#channelSection',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'position': 1,
#     'style': 'verticalList',
#     'type': 'popularUploads'}},
#   {'etag': 'vOeTjKsaQK8YIk5_wV0JinoqrJE',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA.HvnTts3k8Fg',
#    'kind': 'youtube#channelSection',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'position': 2,
#     'style': 'horizontalRow',
#     'type': 'recentActivity'}}],
#  'kind': 'youtube#channelSectionListResponse'}

# %%
channelSections['items'][0]
# Out:
# {'etag': 'XekCe8ltIbhOntsPpZP72KceSOI',
#  'id': 'UC640y4UvDAlya_WOj5U4pfA.ZUhUjN8MMfo',
#  'kind': 'youtube#channelSection',
#  'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#   'position': 0,
#   'style': 'verticalList',
#   'type': 'recentUploads'}}

# %% [markdown]
# ## Resources - **PlaylistItems**

# %% [markdown]
# **nextPageToken** it will be used as the value of pageToken parameter to retrieve the previous page details. It will be useful as when we will be retireve the playlistItems in the above cell then there is maxium limit of 50 Items i.e. only retrieve the 50 items per search.<br>
# So to retrieve the information of all videos, we will be using while loop and nextPageToken as inthe following cell:

# %%
# declare an empty list where we will store the information retrievd of all the uploaded videos on the channel

allVideos = []

# %%
nextPage_token = None

# %%
res = youtube.playlistItems().list(playlistId = UploadId,maxResults = 50,part = 'snippet',pageToken = nextPage_token).execute()

# %%
while 1:
  res = youtube.playlistItems().list(playlistId = UploadId,maxResults = 50,part = 'snippet',pageToken = nextPage_token).execute()

  allVideos += res['items']

  nextPage_token = res.get('nextPageToken')

  if nextPage_token is  None:
    break

print(allVideos)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(allVideos)
# Out:
# 20000

# %% [markdown]
# Now all the information related to all the uploaded videos on this youtube channel got saved inthis list

# %%
print("total number of videos uploaded on this channel is ", len(allVideos))
# Out:
# total number of videos uploaded on this channel is  20000

# %%
allVideos[0]['snippet']
# Out:
# {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#  'channelTitle': 'nptelhrd',
#  'description': 'Vinoth Kumar from KLN College of Engineering, Tamil Nadu feels that the NPTEL course he took up came in handy during the job interviews, where he was able to ace the rounds and bag the offer. He currently works at Mesco Aerospace Work Centre CSIR - National Aerospace Laboratories as a Composite Tool Designer.',
#  'playlistId': 'UU640y4UvDAlya_WOj5U4pfA',
#  'position': 0,
#  'publishedAt': '2020-10-28T12:23:26Z',
#  'resourceId': {'kind': 'youtube#video', 'videoId': '4es_jhBmokE'},
#  'thumbnails': {'default': {'height': 90,
#    'url': 'https://i.ytimg.com/vi/4es_jhBmokE/default.jpg',
#    'width': 120},
#   'high': {'height': 360,
#    'url': 'https://i.ytimg.com/vi/4es_jhBmokE/hqdefault.jpg',
#    'width': 480},
#   'maxres': {'height': 720,
#    'url': 'https://i.ytimg.com/vi/4es_jhBmokE/maxresdefault.jpg',
#    'width': 1280},
#   'medium': {'height': 180,
#    'url': 'https://i.ytimg.com/vi/4es_jhBmokE/mqdefault.jpg',
#    'width': 320},
#   'standard': {'height': 480,
#    'url': 'https://i.ytimg.com/vi/4es_jhBmokE/sddefault.jpg',
#    'width': 640}},
#  'title': 'The NPTEL certification and course that he took up helped Vinoth in cracking job interviews'}

# %%
print("Display the information related to the latest uploaded video on the channel\n")
print("Title of latest video uploaded: "+ allVideos[0]['snippet']['title'])
print("The latest video uploaded on date: "+allVideos[0]['snippet']['publishedAt'])
# Out:
# Display the information related to the latest uploaded video on the channel
#
# Title of latest video uploaded: The NPTEL certification and course that he took up helped Vinoth in cracking job interviews
# The latest video uploaded on date: 2020-10-28T12:23:26Z

# %% [markdown]
# ### Retrieve the videoIDs of all the videos

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], allVideos))
print(len(video_ids))
# Out:
# 20000

# %%
stats = []
for i in range(0, len(video_ids), 40):
  res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
  stats += res['items']
print(stats)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-96864d5bb24a> in <module>()
#       1 stats = []
#       2 for i in range(0, len(video_ids), 40):
# ----> 3   res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
#       4   stats += res['items']
#       5 print(stats)
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     890             method=str(self.method),
#     891             body=self.body,
# --> 892             headers=self.headers,
#     893         )
#     894
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     170         try:
#     171             exception = None
# --> 172             resp, content = http.request(uri, method, *args, **kwargs)
#     173         # Retry on SSL errors and socket timeout errors.
#     174         except _ssl_SSLError as ssl_error:
#
# /usr/local/lib/python3.6/dist-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1989                         headers,
#    1990                         redirections,
# -> 1991                         cachekey,
#    1992                     )
#    1993         except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1649
#    1650         (response, content) = self._conn_request(
# -> 1651             conn, request_uri, method, body, headers
#    1652         )
#    1653
#
# /usr/local/lib/python3.6/dist-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1587                 pass
#    1588             try:
# -> 1589                 response = conn.getresponse()
#    1590             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1591                 # If we get a BadStatusLine on the first try then that means
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
stats[0]

# %%
print((stats[0])['statistics']['commentCount'] )

# %% [markdown]
# # Now we will retrieved the complete details of all videos individually uploaded on the channel- youtube and will save in dataframe as csv file.<br>
# including the:
# * videoTitle
# * videoID
# * likedCount
# * dislikedCount
# * viewCount
# * commentCount

# %%
title=[]
liked=[]
disliked=[]
views=[]
url=[]
comment=[ ]
video_final_ids=[]
publishedDate=[]
video_description=[]

# %%
for i in range(0,2000):
  # print(i)
  i += 1
  title.append((allVideos[i])['snippet']['title'])
  publishedDate.append((allVideos[i])['snippet']['publishedAt']) 
  video_description.append((allVideos[i])['snippet']['description'])
  liked.append(int((stats[i])['statistics']['likeCount']))
  disliked.append(int((stats[i])['statistics']['dislikeCount']))
  views.append(int((stats[i])['statistics']['viewCount']))
  comment.append(int((stats[0])['statistics']['commentCount']))
  videoid.append(allVideos[i]['snippet']['resourceId']['videoId'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-6c68d4fb07f5> in <module>()
#       9   views.append(int((stats[i])['statistics']['viewCount']))
#      10   comment.append(int((stats[0])['statistics']['commentCount']))
# ---> 11   videoid.append(allVideos[i]['snippet']['resourceId']['videoId'])
#
# NameError: name 'videoid' is not defined

# %%
import pandas as pd
data={'title':title,'videoIDS':videoid,'video_description':video_description,'publishedDate':publishedDate,'likes':liked,'dislikes':disliked,'views':views,'comment':comment}
df = pd.DataFrame.from_dict(data, orient='index')
df = df.transpose()

# %%
df.to_csv('ExtractedData.csv',index = False)

# %%
df['title'].iloc[0]
